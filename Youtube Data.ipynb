# %%
from youtube_videos_36 import youtube_search
import pandas as pd

# %%
test = youtube_search("taylor swift")

# %%
test[1]['title']
# Out:
# [u'Taylor Swift - Call It What You Want (Lyric Video)',
#  u'Taylor Swift - \u2026Ready For It?',
#  u'Taylor Swift - Look What You Made Me Do',
#  u'Taylor Swift - Gorgeous (Lyric Video)',
#  u'Taylor Swift - Look What You Made Me Do (Lyric Video)',
#  u'Taylor Swift - Blank Space',
#  u'Taylor Swift - You Belong With Me',
#  u'Taylor Swift - ...Ready For It? (Audio)',
#  u'TAYLOR SWIFT GORGEOUS - PARODY - AWKWARD',
#  u'Taylor Swift - Ready For It LYRICS',
#  u'Taylor Swift - Love Story',
#  u'AN\xc1LISIS: Taylor Swift - Call It What You Want | JJ',
#  u'Taylor Swift - Bad Blood ft. Kendrick Lamar',
#  u'Taylor Swift Reacts To Selena Gomez & Justin Bieber Being Together',
#  u'Taylor Swift- Call It What You Want Reaction',
#  u'CALL IT WHAT YOU WANT (taylor swift) REACTION | abbie riedeman',
#  u'Behind The Scenes: Look What You Made Me Do Video Taylor Swift',
#  u'Taylor Swift - Shake It Off',
#  u'Call It What You Want Taylor Swift - Jemma Johnson Cover',
# ...

# %%
df = pd.DataFrame(data=test[1])
df
# Out:
#    categoryId                 channelId            channelTitle commentCount  \
# 0          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO        44772
# 1          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO       178396
# 2          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO       706211
# 3          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO        65290
# 4          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO       226823
# 5          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO       491118
# 6          10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO       260153
# 7          10  UCqECaJ8Gagnn7YCbPEzWH6g            Taylor Swift        50358
# 8          24  UCuDTc9ztKJbsI6yleL3W2Vg     The Ohana Adventure         2196
# 9          10  UCbDPM9ZoIiE5LfOYJjz2YoA           Lyrics Lovers           14
# 10         10  UCANLZYMidaCbLQFWXBC95Jg         TaylorSwiftVEVO       106324
# ...

# %%
df1 = df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']]
df1.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']
df1
# Out:
#                                                 Title   viewCount  \
# 0   Taylor Swift - Call It What You Want (Lyric Vi...     9487208
# 1                       Taylor Swift - …Ready For It?    61463591
# 2             Taylor Swift - Look What You Made Me Do   670955766
# 3               Taylor Swift - Gorgeous (Lyric Video)    37134976
# 4   Taylor Swift - Look What You Made Me Do (Lyric...    87161830
# 5                          Taylor Swift - Blank Space  2204238453
# 6                   Taylor Swift - You Belong With Me   775861809
# 7             Taylor Swift - ...Ready For It? (Audio)    31190632
# 8            TAYLOR SWIFT GORGEOUS - PARODY - AWKWARD      312764
# 9                  Taylor Swift - Ready For It LYRICS        3733
# 10                          Taylor Swift - Love Story   407019589
# 11  ANÁLISIS: Taylor Swift - Call It What You Want...        6366
# 12        Taylor Swift - Bad Blood ft. Kendrick Lamar  1144804035
# ...

# %%
import numpy as np
numeric_dtype = ['viewCount','commentCount','likeCount','dislikeCount','favoriteCount']
for i in numeric_dtype:
    df1[i] = df[i]

#beyonce = df1[df1['channelTitle']=='beyonceVEVO']
#beyonce
TaylorSwift = df1[df1['channelTitle']=='TaylorSwiftVEVO']
TaylorSwift
# Out:
#                                                 Title   viewCount  \
# 0   Taylor Swift - Call It What You Want (Lyric Vi...     9487208
# 1                       Taylor Swift - …Ready For It?    61463591
# 2             Taylor Swift - Look What You Made Me Do   670955766
# 3               Taylor Swift - Gorgeous (Lyric Video)    37134976
# 4   Taylor Swift - Look What You Made Me Do (Lyric...    87161830
# 5                          Taylor Swift - Blank Space  2204238453
# 6                   Taylor Swift - You Belong With Me   775861809
# 10                          Taylor Swift - Love Story   407019589
# 12        Taylor Swift - Bad Blood ft. Kendrick Lamar  1144804035
# 17                        Taylor Swift - Shake It Off  2428420661
# 21                      Taylor Swift - Wildest Dreams   581729329
# 24  Taylor Swift - We Are Never Ever Getting Back ...   491583210
# 26                                  Taylor Swift - 22   448425278
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
beyonce = beyonce.sort_values(ascending=False,by='viewCount')
plt.bar(range(beyonce.shape[0]),beyonce['viewCount'])
plt.xticks(range(beyonce.shape[0]),beyonce['Title'],rotation=90)
plt.show()

# %%
katy_perry['viewCount']=katy_perry['viewCount'].astype(np.int64)
katy_perry = katy_perry.sort_values(ascending=False,by='viewCount')

plt.bar(range(katy_perry.shape[0]),katy_perry['viewCount'],width=0.3)
plt.xticks(range(katy_perry.shape[0]),katy_perry['Title'],rotation=90)

katy_perry['likeCount']=katy_perry['likeCount'].astype(np.int64)

plt.bar(range(katy_perry.shape[0]),katy_perry['likeCount'],width=0.2)


katy_perry['dislikeCount']=katy_perry['dislikeCount'].astype(np.int64)

plt.bar(range(katy_perry.shape[0]),katy_perry['dislikeCount'],width=0.3)


plt.show()
